# %%
from google.colab import drive
drive.mount('/content/drive')
# !ln -s /content/drive/My\ Drive/ /mydrive
# !ls /mydrive/YoloV4/
# !unzip "/mydrive/YoloV4/train/dataset2.zip" -d /mydrive/YoloV4/train

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15873, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 15873 (delta 12), reused 7 (delta 7), pack-reused 15850 (from 3)
# Receiving objects: 100% (15873/15873), 14.50 MiB | 8.72 MiB/s, done.
# Resolving deltas: 100% (10679/10679), done.

# %% [markdown]
# # 修改配置

# %%
file_path = "darknet/Makefile"

with open(file_path, "r") as file:
    content = file.read()

content = content.replace("GPU=0", "GPU=1")
content = content.replace("OPENCV=0", "OPENCV=1")
content = content.replace("CUDNN=0", "CUDNN=1")
content = content.replace("CUDNN_HALF=0", "CUDNN_HALF=1")

with open(file_path, "w") as file:
    file.write(content)

print("Makefile 修改完成！")
# Out:
# Makefile 修改完成！

# %%
# !cat darknet/Makefile | grep -E "GPU=|OPENCV=|CUDNN=|CUDNN_HALF="
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=1
# OPENCV=1
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores) GPU: Volta, Xavier, Turing, Ampere, Ada and higher

# %% [markdown]
# # 編譯

# %%
# !cd darknet && make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
#       |              ^~~~
# ./src/image_opencv.cpp:1419:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#  1419 |     int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1423:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#  1423 |     int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1427:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#  1427 |     int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1430:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#  1430 |     int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#       |         ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:866:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   866 |         for (int i = 0; i < v.size(); ++i) {
#       |                         ~~^~~~~~~~~~
# ./src/http_stream.cpp:874:33: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   874 |     for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#       |                          ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:893:31: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   893 |     for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#       |                         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:929:28: warning: comparison of integer expressions of different signedness: ‘std::deque<std::vector<detection_t> >::size_type’ {aka ‘long unsigned int’} and ‘int’ [-Wsign-compare]
#   929 |     if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#       |         ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2042:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#  2042 |     const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#       |               ^~~~~
# ./src/gemm.c:2041:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#  2041 |     const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1093:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#  1093 |     while (c = *str++)
#       |            ^
# In file included from /usr/include/string.h:535,
#                  from include/darknet.h:14,
#                  from ./src/utils.h:3,
#                  from ./src/utils.c:4:
# In function ‘strncpy’,
#     inlined from ‘copy_string’ at ./src/utils.c:563:5:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ specified bound depends on the length of the source argument [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/utils.c: In function ‘copy_string’:
# ./src/utils.c:563:22: note: length computed here
#   563 |     strncpy(copy, s, strlen(s)+1);
#       |                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:218:20: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum <anonymous>’ [-Wenum-compare]
#   218 |         if (status != CUDNN_STATUS_SUCCESS)
#       |                    ^~
# ./src/dark_cuda.c: In function ‘cublas_check_error_extended’:
# ./src/dark_cuda.c:252:18: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum cudaError_enum’ [-Wenum-compare]
#   252 |       if (status != CUDA_SUCCESS)
#       |                  ^~
# At top level:
# ./src/dark_cuda.c:275:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#   275 | static cublasHandle_t switchBlasHandle[16];
#       |                       ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:274:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#   274 | static int switchBlasInit[16] = { 0 };
#       |            ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1335:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#  1335 |                         size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#       |                                ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#    79 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#   310 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#   207 |                 int out_index = id;
#       |                     ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:242:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#   242 |                     float max_truth = 0;
#       |                           ^~~~~~~~~
# ./src/softmax_layer.c:421:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   421 |             printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#       |                                                                      ~^                             ~~~~~~~~~~
#       |                                                                       |                             |
#       |                                                                       int                           size_t {aka long unsigned int}
#       |                                                                      %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1289:24: warning: unused variable ‘x’ [-Wunused-variable]
#  1289 |                 int k, x, y;
#       |                        ^
# ./src/data.c:1076:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#  1076 |     float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#       |                                           ^~~~~~~
# ./src/data.c: In function ‘fill_truth_detection’:
# ./src/data.c:431:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:431:27: note: assuming directive output of 8 bytes
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:437:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:437:27: note: assuming directive output of 8 bytes
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:424:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                                 ^~                                                          ~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 61 and 4784 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:417:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   417 |             sprintf(buff, "echo %s \"Wrong annotation: x = 0 or y = 0\" >> bad_label.list", labelpath);
#       |                                 ^~                                                          ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 59 and 4154 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:404:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   404 |             sprintf(buff, "echo %s \"Wrong annotation: class_id = %d. But class_id should be [from 0 to %d]\" >> bad_label.list", labelpath, id, (classes-1));
#       |                                 ^~                                                                                                ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 95 and 4210 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:435:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#   435 |         int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#       |             ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:660:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   660 |         if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#       |                                          ^~~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#   346 |     float one = 1;    // alpha[0], beta[0]
#       |           ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#   344 |     float * c = l.output_gpu;
#       |             ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#   343 |     float * b = l.weights_gpu;
#       |             ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#   342 |     float * a = state.input;
#       |             ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#   341 |     int n = l.outputs;
#       |         ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#   340 |     int k = l.inputs;
#       |         ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#   339 |     int m = l.batch;
#       |         ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1761:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#  1761 |         if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#       |                                          ^~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1893:9: warning: unused variable ‘i’ [-Wunused-variable]
#  1893 |     int i;
#       |         ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:435:40: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#   435 |         classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#       |                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:
# /usr/include/stdlib.h:543:14: note: in a call to allocation function ‘calloc’ declared here
#   543 | extern void *calloc (size_t __nmemb, size_t __size)
#       |              ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#   154 |     switch(iou_kind) {
#       |     ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#   898 |                     float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#   897 |                     float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#   248 |     char *base = "results/comp4_det_test_";
#       |           ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:585:21: warning: statement with no effect [-Wunused-value]
#   585 |                     for (k; buf[k + n] != '\0'; k++)
#       |                     ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:706:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#   706 |         int mkd2 = make_directory(buff2, 0777);
#       |             ^~~~
# ./src/detector.c:704:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#   704 |         int mkd = make_directory(buff, 0777);
#       |             ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1323:24: warning: variable ‘cur_prob’ set but not used [-Wunused-but-set-variable]
#  1323 |                 double cur_prob = 0;
#       |                        ^~~~~~~~
# ./src/detector.c:1344:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#  1344 |         float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#       |               ^~~~~~~~~~~~
# ./src/detector.c:1343:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#  1343 |         float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#       |               ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1872:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#  1872 |             float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#       |                   ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#   208 |     if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#       |                                                   ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#   146 |     int count = 0;
#       |         ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#   855 |     clock_t time;
#       |             ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1283:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#  1283 |         struct timeval tval_before, tval_after, tval_result;
#       |                                                 ^~~~~~~~~~~
# ./src/classifier.c:1283:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#  1283 |         struct timeval tval_before, tval_after, tval_result;
#       |                                     ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#    55 |         float scale = sqrt(2. / l.nweights);
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/representation_layer.c -o obj/representation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:15: warning: unused variable ‘l’ [-Wunused-variable]
#   100 |         layer l = net.layers[net.n - 1];
#       |               ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:63:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#    63 |     int old_h = l->h;
#       |         ^~~~~
# ./src/region_layer.c:62:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#    62 |     int old_w = l->w;
#       |         ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:67:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    67 |     if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#       |                                      ^~~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c:74:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    74 |     if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#       |                                      ^~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ...
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c: In function ‘process_batch’:
# ./src/yolo_layer.c:425:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#   425 |                     int best_match_t = 0;
#       |                         ^~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:705:11: warning: unused variable ‘avg_anyobj’ [-Wunused-variable]
#   705 |     float avg_anyobj = 0;
#       |           ^~~~~~~~~~
# ./src/yolo_layer.c:704:11: warning: unused variable ‘avg_obj’ [-Wunused-variable]
#   704 |     float avg_obj = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:703:11: warning: unused variable ‘avg_cat’ [-Wunused-variable]
#   703 |     float avg_cat = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:702:11: warning: unused variable ‘recall75’ [-Wunused-variable]
#   702 |     float recall75 = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:701:11: warning: unused variable ‘recall’ [-Wunused-variable]
#   701 |     float recall = 0;
#       |           ^~~~~~
# ./src/yolo_layer.c:700:11: warning: unused variable ‘tot_ciou_loss’ [-Wunused-variable]
#   700 |     float tot_ciou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:699:11: warning: unused variable ‘tot_diou_loss’ [-Wunused-variable]
#   699 |     float tot_diou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:696:11: warning: unused variable ‘tot_ciou’ [-Wunused-variable]
#   696 |     float tot_ciou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:695:11: warning: unused variable ‘tot_diou’ [-Wunused-variable]
#   695 |     float tot_diou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:694:11: warning: unused variable ‘tot_giou’ [-Wunused-variable]
#   694 |     float tot_giou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:666:12: warning: unused variable ‘n’ [-Wunused-variable]
#   666 |     int b, n;
#       |            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:70:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    70 |     if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#       |                                      ^~~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c:77:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    77 |     if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#       |                                      ^~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:109:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   109 |         if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c:118:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   118 |         if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %% [markdown]
# # Sample產生

# %%
# 確保 weights 資料夾已經存在
# !mkdir -p darknet/weights

# 使用 wget 下載 yolov4-tiny.weights
# !wget -P darknet/weights https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import os

# 切換到 darknet 目錄
os.chdir('/content/darknet')

# 執行 YOLO 檢測
# !./darknet detector test cfg/coco.data cfg/yolov4-tiny.cfg weights/yolov4-tiny.weights data/person.jpg

# %% [markdown]
# # 訓練

# %% [markdown]
# ### 準備訓練資料

# %%
import os
from PIL import Image

# 設定原始標註文件路徑
input_file = "/content/drive/MyDrive/YoloV4/train/_annotations.txt"  # 替換為您的文件名
output_train_file = "/content/drive/MyDrive/YoloV4/train.txt"
output_label_dir = "/content/drive/MyDrive/YoloV4/train"  # YOLO 標註文件輸出目錄

# 創建輸出標註目錄
os.makedirs(output_label_dir, exist_ok=True)

# 解析標註並生成 YOLO 格式文件
with open(input_file, "r") as infile, open(output_train_file, "w") as outfile:
    for line in infile:
        parts = line.strip().split()  # 按空格分割
        image_path = parts[0]  # 圖片完整路徑
        bbox_info = parts[1:]  # 邊界框資訊

        # 確保圖片存在
        full_image_path = os.path.join(os.path.dirname(input_file), image_path)
        if not os.path.exists(full_image_path):
            print(f"圖片不存在: {full_image_path}")
            continue

        # 獲取圖片大小
        with Image.open(full_image_path) as img:
            img_width, img_height = img.size

        # 生成對應的 YOLO 標註文件
        label_file = os.path.join(output_label_dir, os.path.splitext(os.path.basename(image_path))[0] + ".txt")
        with open(label_file, "w") as label_outfile:
            for bbox in bbox_info:
                try:
                    bbox_parts = bbox.split(",")
                    x_min, y_min, x_max, y_max, class_id = map(int, bbox_parts)

                    # 計算 YOLO 格式 (x_center, y_center, width, height)
                    x_center = (x_min + x_max) / 2.0
                    y_center = (y_min + y_max) / 2.0
                    width = x_max - x_min
                    height = y_max - y_min

                    # 將座標轉換為相對比例
                    x_center /= img_width
                    y_center /= img_height
                    width /= img_width
                    height /= img_height

                    # 檢查座標是否有效
                    if not (0 <= x_center <= 1 and 0 <= y_center <= 1 and width > 0 and height > 0):
                        print(f"無效的標註座標: {bbox} 在 {image_path}")
                        continue

                    # 保存 YOLO 格式
                    label_outfile.write(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
                except ValueError:
                    print(f"無法解析標註: {bbox} 在 {image_path}")

        # 將圖片路徑寫入 train.txt
        outfile.write(f"{os.path.join(output_label_dir, image_path)}\n")

print(f"已生成 YOLO 標註文件至 {output_label_dir}")
print(f"已生成 {output_train_file}")
# Out:
# 已生成 YOLO 標註文件至 /content/drive/MyDrive/YoloV4/train
# 已生成 /content/drive/MyDrive/YoloV4/train.txt

# %%
# prompt: 找到/mydrive/YoloV4/train/裡面所有.jpg 匯出所有的名稱train.txt 給yolo使用

import os

# 設定圖片目錄
image_dir = "/mydrive/YoloV4/train"

# 建立 train.txt 文件
with open("/mydrive/YoloV4/train2.txt", "w") as train_file:
    # 遍歷圖片目錄
    for filename in os.listdir(image_dir):
        # 檢查檔案是否為 .jpg 檔案
        if filename.endswith(".jpg"):
            # 將圖片完整路徑寫入 train.txt
            train_file.write(os.path.join(image_dir, filename) + "\n")

print("已生成 train2.txt 文件。")
# Out:
# 已生成 train2.txt 文件。

# %% [markdown]
# ### 訓練

# %%
# 執行 YOLO 檢測
# !/content/darknet/darknet detector train /content/drive/MyDrive/YoloV4/coco.data /content/drive/MyDrive/YoloV4/yolov4-tiny-obj.cfg /content/drive/MyDrive/YoloV4/yolov4-tiny.weights -dont_show
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.853852), count: 7, class_loss = 0.625841, iou_loss = 2.432543, total_loss = 3.058384
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.704372), count: 4, class_loss = 0.590211, iou_loss = 8.530247, total_loss = 9.120458
#  total_bbox = 396755, rewritten_bbox = 0.964071 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.869894), count: 2, class_loss = 0.000757, iou_loss = 0.628555, total_loss = 0.629312
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.863148), count: 2, class_loss = 0.019110, iou_loss = 2.267149, total_loss = 2.286258
#  total_bbox = 396759, rewritten_bbox = 0.964061 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.787499), count: 5, class_loss = 0.482155, iou_loss = 0.982107, total_loss = 1.464261
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.821133), count: 2, class_loss = 0.524107, iou_loss = 10.726116, total_loss = 11.250223
#  total_bbox = 396766, rewritten_bbox = 0.964044 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.837789), count: 3, class_loss = 0.301488, iou_loss = 0.564415, total_loss = 0.865903
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.801272), count: 4, class_loss = 0.502124, iou_loss = 3.935061, total_loss = 4.437184
#  total_bbox = 396773, rewritten_bbox = 0.964027 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.814447), count: 8, class_loss = 1.076560, iou_loss = 1.417534, total_loss = 2.494094
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.719066), count: 10, class_loss = 1.868970, iou_loss = 32.703213, total_loss = 34.572182
#  total_bbox = 396791, rewritten_bbox = 0.963984 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.855791), count: 3, class_loss = 0.304577, iou_loss = 1.828367, total_loss = 2.132943
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.643677), count: 1, class_loss = 0.333275, iou_loss = 1.961206, total_loss = 2.294480
#  total_bbox = 396795, rewritten_bbox = 0.963974 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1907/2000: loss=0.5 hours left=0.1
#  1907: 0.500361, 0.679620 avg loss, 0.000026 rate, 2.380612 seconds, 122048 images, 0.091514 hours left
# Loaded: 0.000075 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.840062), count: 6, class_loss = 0.198324, iou_loss = 1.549096, total_loss = 1.747420
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.791770), count: 6, class_loss = 1.008004, iou_loss = 14.194677, total_loss = 15.202682
#  total_bbox = 396807, rewritten_bbox = 0.963945 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.820350), count: 4, class_loss = 0.592856, iou_loss = 1.571586, total_loss = 2.164442
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.832789), count: 2, class_loss = 0.100984, iou_loss = 4.508314, total_loss = 4.609297
#  total_bbox = 396813, rewritten_bbox = 0.964182 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.794221), count: 2, class_loss = 0.232584, iou_loss = 0.678738, total_loss = 0.911321
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.801858), count: 9, class_loss = 1.049369, iou_loss = 40.385647, total_loss = 41.435017
#  total_bbox = 396824, rewritten_bbox = 0.964155 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.860239), count: 9, class_loss = 0.037965, iou_loss = 2.642437, total_loss = 2.680402
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.786558), count: 13, class_loss = 1.627535, iou_loss = 31.465208, total_loss = 33.092743
#  total_bbox = 396846, rewritten_bbox = 0.964102 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.843519), count: 5, class_loss = 0.533890, iou_loss = 2.233268, total_loss = 2.767158
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.531885), count: 3, class_loss = 0.511617, iou_loss = 10.385092, total_loss = 10.896708
#  total_bbox = 396854, rewritten_bbox = 0.964082 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.792184), count: 9, class_loss = 0.930416, iou_loss = 2.005597, total_loss = 2.936013
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.336991), count: 1, class_loss = 0.310627, iou_loss = 0.295261, total_loss = 0.605888
#  total_bbox = 396864, rewritten_bbox = 0.964058 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.780935), count: 10, class_loss = 1.707938, iou_loss = 2.250132, total_loss = 3.958070
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.850382), count: 3, class_loss = 0.595802, iou_loss = 6.458339, total_loss = 7.054142
#  total_bbox = 396877, rewritten_bbox = 0.964027 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.820976), count: 4, class_loss = 0.050176, iou_loss = 1.018624, total_loss = 1.068801
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.856514), count: 4, class_loss = 0.451135, iou_loss = 6.516806, total_loss = 6.967940
#  total_bbox = 396885, rewritten_bbox = 0.964007 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.892181), count: 4, class_loss = 0.007911, iou_loss = 1.409411, total_loss = 1.417322
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.795831), count: 8, class_loss = 0.917459, iou_loss = 21.394184, total_loss = 22.311644
#  total_bbox = 396897, rewritten_bbox = 0.963978 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.838442), count: 11, class_loss = 0.779888, iou_loss = 3.760485, total_loss = 4.540373
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.744324), count: 10, class_loss = 1.309357, iou_loss = 24.041027, total_loss = 25.350384
#  total_bbox = 396918, rewritten_bbox = 0.963927 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.847077), count: 16, class_loss = 0.476584, iou_loss = 3.546179, total_loss = 4.022762
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.835695), count: 5, class_loss = 0.714753, iou_loss = 17.339025, total_loss = 18.053780
#  total_bbox = 396939, rewritten_bbox = 0.963876 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.637629), count: 4, class_loss = 0.952448, iou_loss = 0.926686, total_loss = 1.879134
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.897864), count: 4, class_loss = 0.143051, iou_loss = 4.344152, total_loss = 4.487204
#  total_bbox = 396947, rewritten_bbox = 0.963857 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.765693), count: 3, class_loss = 0.407417, iou_loss = 0.583934, total_loss = 0.991351
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.479835), count: 2, class_loss = 0.193759, iou_loss = 12.436130, total_loss = 12.629889
#  total_bbox = 396952, rewritten_bbox = 0.963844 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.808899), count: 3, class_loss = 0.214875, iou_loss = 0.856824, total_loss = 1.071699
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.765783), count: 15, class_loss = 1.105877, iou_loss = 62.088287, total_loss = 63.194164
#  total_bbox = 396970, rewritten_bbox = 0.963801 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.827833), count: 4, class_loss = 0.469379, iou_loss = 0.953459, total_loss = 1.422838
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.797526), count: 2, class_loss = 0.014077, iou_loss = 2.655693, total_loss = 2.669770
#  total_bbox = 396976, rewritten_bbox = 0.963786 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.821788), count: 1, class_loss = 0.274255, iou_loss = 0.294854, total_loss = 0.569109
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.856657), count: 5, class_loss = 0.163660, iou_loss = 5.661980, total_loss = 5.825641
#  total_bbox = 396982, rewritten_bbox = 0.963772 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1908/2000: loss=0.6 hours left=0.1
#  1908: 0.568977, 0.668556 avg loss, 0.000026 rate, 2.261884 seconds, 122112 images, 0.091214 hours left
# Loaded: 0.000065 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.888729), count: 4, class_loss = 0.153261, iou_loss = 1.221970, total_loss = 1.375231
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.385147), count: 1, class_loss = 0.245315, iou_loss = 8.713696, total_loss = 8.959010
#  total_bbox = 396987, rewritten_bbox = 0.963760 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.647999), count: 6, class_loss = 0.860699, iou_loss = 0.939346, total_loss = 1.800045
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.655036), count: 4, class_loss = 0.432540, iou_loss = 4.913584, total_loss = 5.346124
#  total_bbox = 396997, rewritten_bbox = 0.963987 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.797861), count: 5, class_loss = 0.390838, iou_loss = 1.048051, total_loss = 1.438889
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.840660), count: 4, class_loss = 0.400230, iou_loss = 12.180573, total_loss = 12.580803
#  total_bbox = 397006, rewritten_bbox = 0.964217 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.835801), count: 3, class_loss = 0.403429, iou_loss = 1.200471, total_loss = 1.603900
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.835126), count: 2, class_loss = 0.201162, iou_loss = 2.125524, total_loss = 2.326686
#  total_bbox = 397011, rewritten_bbox = 0.964205 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.825774), count: 6, class_loss = 0.615166, iou_loss = 2.496034, total_loss = 3.111200
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.784768), count: 1, class_loss = 0.275595, iou_loss = 0.757970, total_loss = 1.033565
#  total_bbox = 397018, rewritten_bbox = 0.964188 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.719126), count: 14, class_loss = 2.315503, iou_loss = 2.918557, total_loss = 5.234060
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.808117), count: 7, class_loss = 1.035151, iou_loss = 11.481234, total_loss = 12.516385
#  total_bbox = 397039, rewritten_bbox = 0.964137 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.846411), count: 5, class_loss = 0.332072, iou_loss = 2.110348, total_loss = 2.442420
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.686752), count: 6, class_loss = 0.933176, iou_loss = 12.148685, total_loss = 13.081861
#  total_bbox = 397050, rewritten_bbox = 0.964110 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.812715), count: 13, class_loss = 0.431442, iou_loss = 3.513744, total_loss = 3.945186
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.728975), count: 5, class_loss = 0.801702, iou_loss = 21.767530, total_loss = 22.569233
#  total_bbox = 397068, rewritten_bbox = 0.964067 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.874961), count: 4, class_loss = 0.252834, iou_loss = 1.575864, total_loss = 1.828698
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.872880), count: 2, class_loss = 0.014006, iou_loss = 2.025012, total_loss = 2.039017
#  total_bbox = 397074, rewritten_bbox = 0.964052 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.818737), count: 18, class_loss = 1.803294, iou_loss = 4.794586, total_loss = 6.597881
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.756899), count: 15, class_loss = 2.640421, iou_loss = 18.311359, total_loss = 20.951780
#  total_bbox = 397107, rewritten_bbox = 0.963972 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.827650), count: 7, class_loss = 0.712790, iou_loss = 1.583829, total_loss = 2.296620
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.824639), count: 4, class_loss = 0.523797, iou_loss = 4.191088, total_loss = 4.714884
#  total_bbox = 397118, rewritten_bbox = 0.963945 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.874184), count: 5, class_loss = 0.157552, iou_loss = 1.847426, total_loss = 2.004978
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.687577), count: 2, class_loss = 0.253720, iou_loss = 4.567953, total_loss = 4.821673
#  total_bbox = 397125, rewritten_bbox = 0.963928 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.830375), count: 10, class_loss = 0.452361, iou_loss = 2.775143, total_loss = 3.227504
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.755812), count: 3, class_loss = 0.089038, iou_loss = 3.953639, total_loss = 4.042676
#  total_bbox = 397138, rewritten_bbox = 0.963897 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.759984), count: 5, class_loss = 0.490229, iou_loss = 2.050631, total_loss = 2.540860
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.626025), count: 3, class_loss = 0.582759, iou_loss = 3.395428, total_loss = 3.978188
#  total_bbox = 397146, rewritten_bbox = 0.963877 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.817974), count: 6, class_loss = 0.509683, iou_loss = 1.892538, total_loss = 2.402221
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.829097), count: 6, class_loss = 0.393217, iou_loss = 10.585746, total_loss = 10.978963
#  total_bbox = 397158, rewritten_bbox = 0.963848 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.847794), count: 4, class_loss = 0.009852, iou_loss = 4.983875, total_loss = 4.993727
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.892060), count: 2, class_loss = 0.002477, iou_loss = 2.150826, total_loss = 2.153303
#  total_bbox = 397164, rewritten_bbox = 0.964085 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1909/2000: loss=0.6 hours left=0.1
#  1909: 0.588684, 0.660568 avg loss, 0.000026 rate, 2.353976 seconds, 122176 images, 0.090880 hours left
# Loaded: 0.000074 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.827875), count: 10, class_loss = 0.967759, iou_loss = 2.396982, total_loss = 3.364742
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.782621), count: 8, class_loss = 0.835128, iou_loss = 15.593389, total_loss = 16.428516
#  total_bbox = 397182, rewritten_bbox = 0.964042 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.895835), count: 4, class_loss = 0.003093, iou_loss = 1.627223, total_loss = 1.630316
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.809729), count: 5, class_loss = 0.365842, iou_loss = 17.986164, total_loss = 18.352005
#  total_bbox = 397191, rewritten_bbox = 0.964020 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.748823), count: 6, class_loss = 0.764415, iou_loss = 1.917203, total_loss = 2.681618
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.822908), count: 6, class_loss = 0.724338, iou_loss = 7.675140, total_loss = 8.399478
#  total_bbox = 397203, rewritten_bbox = 0.964494 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.795896), count: 10, class_loss = 1.653316, iou_loss = 2.806280, total_loss = 4.459595
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.717835), count: 12, class_loss = 2.261963, iou_loss = 12.616699, total_loss = 14.878662
#  total_bbox = 397225, rewritten_bbox = 0.964441 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.845494), count: 15, class_loss = 0.549799, iou_loss = 5.199144, total_loss = 5.748943
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.707269), count: 9, class_loss = 1.278956, iou_loss = 12.672345, total_loss = 13.951302
#  total_bbox = 397249, rewritten_bbox = 0.964383 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.799461), count: 3, class_loss = 0.424623, iou_loss = 0.742505, total_loss = 1.167129
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.881135), count: 1, class_loss = 0.158516, iou_loss = 0.902938, total_loss = 1.061453
#  total_bbox = 397253, rewritten_bbox = 0.964373 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.886992), count: 5, class_loss = 0.050072, iou_loss = 2.211541, total_loss = 2.261613
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.765843), count: 10, class_loss = 1.181799, iou_loss = 51.012001, total_loss = 52.193802
#  total_bbox = 397268, rewritten_bbox = 0.964336 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.799969), count: 3, class_loss = 0.629735, iou_loss = 0.853969, total_loss = 1.483704
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.806621), count: 3, class_loss = 0.334123, iou_loss = 2.829880, total_loss = 3.164004
#  total_bbox = 397274, rewritten_bbox = 0.964322 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.881501), count: 6, class_loss = 0.095201, iou_loss = 2.096911, total_loss = 2.192112
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.675791), count: 9, class_loss = 2.040354, iou_loss = 7.920640, total_loss = 9.960995
#  total_bbox = 397289, rewritten_bbox = 0.964285 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.653397), count: 7, class_loss = 1.696414, iou_loss = 0.516226, total_loss = 2.212640
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.771961), count: 1, class_loss = 0.056185, iou_loss = 0.783966, total_loss = 0.840151
#  total_bbox = 397297, rewritten_bbox = 0.964266 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.798110), count: 12, class_loss = 1.074878, iou_loss = 3.433352, total_loss = 4.508230
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.525967), count: 2, class_loss = 0.784392, iou_loss = 10.649197, total_loss = 11.433588
#  total_bbox = 397311, rewritten_bbox = 0.964232 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.708005), count: 6, class_loss = 0.737133, iou_loss = 1.603126, total_loss = 2.340259
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.741854), count: 8, class_loss = 1.526040, iou_loss = 18.314173, total_loss = 19.840214
#  total_bbox = 397325, rewritten_bbox = 0.964450 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.785517), count: 3, class_loss = 0.249524, iou_loss = 0.745113, total_loss = 0.994637
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.861076), count: 3, class_loss = 0.301304, iou_loss = 3.771550, total_loss = 4.072854
#  total_bbox = 397331, rewritten_bbox = 0.964435 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.824783), count: 15, class_loss = 2.078812, iou_loss = 3.223662, total_loss = 5.302474
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.818415), count: 7, class_loss = 1.170075, iou_loss = 13.266113, total_loss = 14.436188
#  total_bbox = 397353, rewritten_bbox = 0.964382 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.775682), count: 5, class_loss = 0.486530, iou_loss = 0.925841, total_loss = 1.412371
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.766134), count: 6, class_loss = 1.027039, iou_loss = 8.212144, total_loss = 9.239182
#  total_bbox = 397364, rewritten_bbox = 0.964355 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.774288), count: 16, class_loss = 2.292788, iou_loss = 3.122447, total_loss = 5.415235
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.747399), count: 3, class_loss = 0.364642, iou_loss = 4.076931, total_loss = 4.441573
#  total_bbox = 397383, rewritten_bbox = 0.964309 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1910/2000: loss=0.9 hours left=0.1
#  1910: 0.883975, 0.682909 avg loss, 0.000026 rate, 2.495326 seconds, 122240 images, 0.090566 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 319.68 MB
#  CUDA allocate done!
# Loaded: 0.062677 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.853443), count: 5, class_loss = 0.241540, iou_loss = 2.153753, total_loss = 2.395293
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.759376), count: 19, class_loss = 3.734132, iou_loss = 37.091995, total_loss = 40.826126
#  total_bbox = 397407, rewritten_bbox = 0.964251 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.842151), count: 7, class_loss = 0.315676, iou_loss = 2.988185, total_loss = 3.303861
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.663533), count: 2, class_loss = 0.461648, iou_loss = 1.652379, total_loss = 2.114027
#  total_bbox = 397416, rewritten_bbox = 0.964229 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.848207), count: 9, class_loss = 0.561481, iou_loss = 2.485394, total_loss = 3.046875
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.810361), count: 8, class_loss = 0.816836, iou_loss = 13.687149, total_loss = 14.503984
#  total_bbox = 397433, rewritten_bbox = 0.964188 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.877836), count: 7, class_loss = 0.262125, iou_loss = 3.068202, total_loss = 3.330328
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.756973), count: 15, class_loss = 2.265980, iou_loss = 54.970020, total_loss = 57.236000
#  total_bbox = 397455, rewritten_bbox = 0.964134 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.797190), count: 11, class_loss = 1.046443, iou_loss = 3.363559, total_loss = 4.410002
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.674856), count: 5, class_loss = 1.060526, iou_loss = 7.813081, total_loss = 8.873607
#  total_bbox = 397471, rewritten_bbox = 0.964095 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.758932), count: 14, class_loss = 2.845402, iou_loss = 2.686789, total_loss = 5.532191
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.750973), count: 7, class_loss = 1.080168, iou_loss = 12.051947, total_loss = 13.132115
#  total_bbox = 397492, rewritten_bbox = 0.964045 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.898997), count: 3, class_loss = 0.091237, iou_loss = 1.343492, total_loss = 1.434728
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.798106), count: 4, class_loss = 0.282652, iou_loss = 5.081900, total_loss = 5.364552
#  total_bbox = 397499, rewritten_bbox = 0.964028 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.821639), count: 11, class_loss = 1.047449, iou_loss = 2.672826, total_loss = 3.720275
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.744740), count: 3, class_loss = 0.558844, iou_loss = 6.257598, total_loss = 6.816442
#  total_bbox = 397513, rewritten_bbox = 0.963994 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.799626), count: 11, class_loss = 1.278749, iou_loss = 4.201237, total_loss = 5.479986
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.750334), count: 1, class_loss = 0.281677, iou_loss = 1.186953, total_loss = 1.468630
#  total_bbox = 397525, rewritten_bbox = 0.964216 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.745611), count: 4, class_loss = 0.501102, iou_loss = 1.428568, total_loss = 1.929670
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.000000), count: 1, class_loss = 0.108136, iou_loss = 0.000000, total_loss = 0.108136
#  total_bbox = 397529, rewritten_bbox = 0.964206 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.700386), count: 4, class_loss = 0.775766, iou_loss = 0.762585, total_loss = 1.538351
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.662649), count: 2, class_loss = 0.497384, iou_loss = 2.431519, total_loss = 2.928903
#  total_bbox = 397535, rewritten_bbox = 0.964192 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.828112), count: 4, class_loss = 0.009054, iou_loss = 1.585509, total_loss = 1.594563
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.785911), count: 3, class_loss = 0.307217, iou_loss = 2.579417, total_loss = 2.886635
#  total_bbox = 397542, rewritten_bbox = 0.964175 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.850700), count: 9, class_loss = 0.451976, iou_loss = 2.563732, total_loss = 3.015708
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.734716), count: 1, class_loss = 0.047916, iou_loss = 12.316479, total_loss = 12.364394
#  total_bbox = 397552, rewritten_bbox = 0.964151 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.825659), count: 21, class_loss = 2.029135, iou_loss = 6.940681, total_loss = 8.969816
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.736623), count: 9, class_loss = 1.620037, iou_loss = 26.756868, total_loss = 28.376905
#  total_bbox = 397582, rewritten_bbox = 0.964078 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.771524), count: 4, class_loss = 1.006279, iou_loss = 0.688152, total_loss = 1.694432
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.864925), count: 1, class_loss = 0.369258, iou_loss = 1.392654, total_loss = 1.761912
#  total_bbox = 397587, rewritten_bbox = 0.964066 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.875200), count: 4, class_loss = 0.395145, iou_loss = 1.631493, total_loss = 2.026638
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.778738), count: 5, class_loss = 0.721118, iou_loss = 4.782377, total_loss = 5.503495
#  total_bbox = 397596, rewritten_bbox = 0.964044 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1911/2000: loss=0.8 hours left=0.1
#  1911: 0.849630, 0.699581 avg loss, 0.000026 rate, 2.786293 seconds, 122304 images, 0.090284 hours left
# Loaded: 0.000081 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.750870), count: 6, class_loss = 0.634137, iou_loss = 2.323133, total_loss = 2.957270
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.789491), count: 1, class_loss = 0.311876, iou_loss = 0.600414, total_loss = 0.912291
#  total_bbox = 397603, rewritten_bbox = 0.964278 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.925674), count: 1, class_loss = 0.245638, iou_loss = 0.025255, total_loss = 0.270893
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.812505), count: 3, class_loss = 0.112951, iou_loss = 7.031688, total_loss = 7.144639
#  total_bbox = 397607, rewritten_bbox = 0.964269 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.831471), count: 7, class_loss = 0.582892, iou_loss = 2.105549, total_loss = 2.688441
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.848321), count: 3, class_loss = 0.768003, iou_loss = 9.734662, total_loss = 10.502665
#  total_bbox = 397617, rewritten_bbox = 0.964244 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.718361), count: 2, class_loss = 0.289535, iou_loss = 0.372997, total_loss = 0.662532
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.837004), count: 5, class_loss = 0.885128, iou_loss = 10.735599, total_loss = 11.620727
#  total_bbox = 397624, rewritten_bbox = 0.964227 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.812596), count: 7, class_loss = 0.633928, iou_loss = 2.782624, total_loss = 3.416552
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.675602), count: 4, class_loss = 0.824629, iou_loss = 4.743446, total_loss = 5.568075
#  total_bbox = 397635, rewritten_bbox = 0.964201 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.740257), count: 5, class_loss = 0.252843, iou_loss = 1.694707, total_loss = 1.947550
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.841051), count: 5, class_loss = 0.393482, iou_loss = 13.084863, total_loss = 13.478345
#  total_bbox = 397645, rewritten_bbox = 0.964177 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.773346), count: 2, class_loss = 0.728424, iou_loss = 0.393046, total_loss = 1.121471
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.853322), count: 5, class_loss = 0.241517, iou_loss = 10.361137, total_loss = 10.602654
#  total_bbox = 397652, rewritten_bbox = 0.964160 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.769345), count: 15, class_loss = 1.469909, iou_loss = 4.395567, total_loss = 5.865476
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.711380), count: 8, class_loss = 1.306118, iou_loss = 25.572306, total_loss = 26.878424
#  total_bbox = 397675, rewritten_bbox = 0.964104 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.835861), count: 7, class_loss = 0.983174, iou_loss = 1.912487, total_loss = 2.895661
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.850902), count: 3, class_loss = 0.552546, iou_loss = 3.762346, total_loss = 4.314891
#  total_bbox = 397685, rewritten_bbox = 0.964080 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.599746), count: 3, class_loss = 0.392271, iou_loss = 0.958649, total_loss = 1.350920
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.873792), count: 1, class_loss = 0.046391, iou_loss = 1.233431, total_loss = 1.279822
#  total_bbox = 397689, rewritten_bbox = 0.964070 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.787915), count: 12, class_loss = 1.442694, iou_loss = 3.149173, total_loss = 4.591867
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.706915), count: 5, class_loss = 0.735368, iou_loss = 9.987419, total_loss = 10.722788
#  total_bbox = 397706, rewritten_bbox = 0.964532 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.711975), count: 4, class_loss = 0.582911, iou_loss = 0.910264, total_loss = 1.493175
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.764363), count: 5, class_loss = 1.003602, iou_loss = 5.519240, total_loss = 6.522842
#  total_bbox = 397715, rewritten_bbox = 0.964510 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.798648), count: 15, class_loss = 2.491228, iou_loss = 5.639277, total_loss = 8.130505
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.747846), count: 8, class_loss = 1.898478, iou_loss = 11.647585, total_loss = 13.546062
#  total_bbox = 397738, rewritten_bbox = 0.964454 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.825235), count: 5, class_loss = 0.271603, iou_loss = 1.445941, total_loss = 1.717545
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.687236), count: 3, class_loss = 0.416381, iou_loss = 10.771832, total_loss = 11.188213
#  total_bbox = 397746, rewritten_bbox = 0.964435 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.806785), count: 12, class_loss = 0.898370, iou_loss = 3.749163, total_loss = 4.647532
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.680623), count: 8, class_loss = 1.840422, iou_loss = 23.700768, total_loss = 25.541189
#  total_bbox = 397766, rewritten_bbox = 0.964638 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.839044), count: 14, class_loss = 1.016542, iou_loss = 4.427044, total_loss = 5.443586
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.785406), count: 16, class_loss = 2.477992, iou_loss = 22.970146, total_loss = 25.448139
#  total_bbox = 397796, rewritten_bbox = 0.964565 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1912/2000: loss=0.8 hours left=0.1
#  1912: 0.839175, 0.713541 avg loss, 0.000026 rate, 2.743531 seconds, 122368 images, 0.090086 hours left
# Loaded: 0.000066 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.790123), count: 3, class_loss = 0.289555, iou_loss = 1.113887, total_loss = 1.403443
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.828287), count: 3, class_loss = 0.479555, iou_loss = 15.051773, total_loss = 15.531328
#  total_bbox = 397802, rewritten_bbox = 0.964550 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.862761), count: 6, class_loss = 0.059171, iou_loss = 2.294881, total_loss = 2.354052
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.732482), count: 12, class_loss = 1.880202, iou_loss = 46.221645, total_loss = 48.101849
#  total_bbox = 397820, rewritten_bbox = 0.964507 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.862161), count: 6, class_loss = 0.526958, iou_loss = 2.117155, total_loss = 2.644112
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.812148), count: 8, class_loss = 1.670256, iou_loss = 8.596633, total_loss = 10.266889
#  total_bbox = 397834, rewritten_bbox = 0.964473 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.841062), count: 2, class_loss = 0.010951, iou_loss = 0.736239, total_loss = 0.747190
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.863780), count: 5, class_loss = 0.323616, iou_loss = 9.867513, total_loss = 10.191129
#  total_bbox = 397841, rewritten_bbox = 0.964456 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.753979), count: 3, class_loss = 0.462953, iou_loss = 0.726810, total_loss = 1.189763
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.791193), count: 3, class_loss = 0.287454, iou_loss = 2.993368, total_loss = 3.280821
#  total_bbox = 397847, rewritten_bbox = 0.964441 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.800334), count: 4, class_loss = 0.427646, iou_loss = 0.911956, total_loss = 1.339602
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.811784), count: 1, class_loss = 0.022034, iou_loss = 0.955200, total_loss = 0.977235
#  total_bbox = 397852, rewritten_bbox = 0.964429 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.881779), count: 2, class_loss = 0.040531, iou_loss = 1.141261, total_loss = 1.181791
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.000000), count: 1, class_loss = 0.001588, iou_loss = 0.000000, total_loss = 0.001588
#  total_bbox = 397854, rewritten_bbox = 0.964424 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.814815), count: 2, class_loss = 0.193789, iou_loss = 0.669546, total_loss = 0.863335
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.914016), count: 2, class_loss = 0.008399, iou_loss = 2.399243, total_loss = 2.407642
#  total_bbox = 397858, rewritten_bbox = 0.964414 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.833319), count: 10, class_loss = 0.564750, iou_loss = 4.475164, total_loss = 5.039914
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.759764), count: 10, class_loss = 2.040686, iou_loss = 17.641476, total_loss = 19.682161
#  total_bbox = 397878, rewritten_bbox = 0.964617 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.825435), count: 12, class_loss = 1.200384, iou_loss = 3.405816, total_loss = 4.606200
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.758805), count: 8, class_loss = 1.599533, iou_loss = 10.247878, total_loss = 11.847411
#  total_bbox = 397898, rewritten_bbox = 0.965071 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.676419), count: 3, class_loss = 0.563424, iou_loss = 0.341515, total_loss = 0.904940
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.868726), count: 1, class_loss = 0.005264, iou_loss = 1.516033, total_loss = 1.521297
#  total_bbox = 397902, rewritten_bbox = 0.965062 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.830134), count: 12, class_loss = 0.224203, iou_loss = 4.165622, total_loss = 4.389825
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.804712), count: 6, class_loss = 0.920956, iou_loss = 6.646810, total_loss = 7.567766
#  total_bbox = 397920, rewritten_bbox = 0.965018 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.739474), count: 8, class_loss = 1.332912, iou_loss = 2.882314, total_loss = 4.215226
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.566818), count: 2, class_loss = 0.732932, iou_loss = 5.844500, total_loss = 6.577431
#  total_bbox = 397930, rewritten_bbox = 0.964994 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.866132), count: 7, class_loss = 0.561676, iou_loss = 2.362640, total_loss = 2.924316
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.611019), count: 4, class_loss = 0.778599, iou_loss = 46.761158, total_loss = 47.539757
#  total_bbox = 397941, rewritten_bbox = 0.964967 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.867736), count: 3, class_loss = 0.162148, iou_loss = 1.494718, total_loss = 1.656866
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.857927), count: 2, class_loss = 0.130920, iou_loss = 2.848519, total_loss = 2.979438
#  total_bbox = 397946, rewritten_bbox = 0.965206 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.789266), count: 10, class_loss = 1.398560, iou_loss = 2.407017, total_loss = 3.805577
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.785364), count: 9, class_loss = 2.295875, iou_loss = 16.526686, total_loss = 18.822561
#  total_bbox = 397965, rewritten_bbox = 0.965160 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1913/2000: loss=0.7 hours left=0.1
#  1913: 0.665811, 0.708768 avg loss, 0.000026 rate, 2.605231 seconds, 122432 images, 0.089856 hours left
# Loaded: 0.000078 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.871634), count: 5, class_loss = 0.246762, iou_loss = 2.149193, total_loss = 2.395955
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.851224), count: 2, class_loss = 0.027602, iou_loss = 2.282286, total_loss = 2.309888
#  total_bbox = 397972, rewritten_bbox = 0.965143 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.758698), count: 3, class_loss = 0.307923, iou_loss = 0.999922, total_loss = 1.307845
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.723109), count: 8, class_loss = 2.070539, iou_loss = 29.588118, total_loss = 31.658657
#  total_bbox = 397983, rewritten_bbox = 0.965117 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.832076), count: 8, class_loss = 1.447055, iou_loss = 2.535154, total_loss = 3.982209
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.813621), count: 5, class_loss = 0.800783, iou_loss = 5.635592, total_loss = 6.436375
#  total_bbox = 397996, rewritten_bbox = 0.965085 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.857052), count: 12, class_loss = 0.181722, iou_loss = 6.147161, total_loss = 6.328884
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.730511), count: 8, class_loss = 1.550511, iou_loss = 64.284416, total_loss = 65.834930
#  total_bbox = 398016, rewritten_bbox = 0.965037 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.775025), count: 8, class_loss = 1.153975, iou_loss = 2.355474, total_loss = 3.509449
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.808908), count: 5, class_loss = 0.505288, iou_loss = 7.738137, total_loss = 8.243425
#  total_bbox = 398029, rewritten_bbox = 0.965005 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.805148), count: 14, class_loss = 1.469476, iou_loss = 4.524245, total_loss = 5.993721
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.646875), count: 9, class_loss = 2.199996, iou_loss = 37.046150, total_loss = 39.246147
#  total_bbox = 398052, rewritten_bbox = 0.964949 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.732728), count: 11, class_loss = 0.829906, iou_loss = 3.630172, total_loss = 4.460079
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.822707), count: 9, class_loss = 1.389239, iou_loss = 13.238419, total_loss = 14.627658
#  total_bbox = 398072, rewritten_bbox = 0.964901 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.854216), count: 5, class_loss = 0.767525, iou_loss = 1.256114, total_loss = 2.023638
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.659269), count: 6, class_loss = 0.906135, iou_loss = 7.163504, total_loss = 8.069639
#  total_bbox = 398083, rewritten_bbox = 0.964874 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.811374), count: 10, class_loss = 0.811810, iou_loss = 2.101847, total_loss = 2.913658
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.858647), count: 4, class_loss = 0.634496, iou_loss = 6.412294, total_loss = 7.046791
#  total_bbox = 398097, rewritten_bbox = 0.964840 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.868204), count: 3, class_loss = 0.000393, iou_loss = 1.141101, total_loss = 1.141494
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.826113), count: 2, class_loss = 0.230793, iou_loss = 2.483761, total_loss = 2.714554
#  total_bbox = 398102, rewritten_bbox = 0.964828 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.819827), count: 12, class_loss = 0.591252, iou_loss = 3.024908, total_loss = 3.616160
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.782907), count: 3, class_loss = 0.631465, iou_loss = 12.693502, total_loss = 13.324967
#  total_bbox = 398117, rewritten_bbox = 0.964792 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.830667), count: 12, class_loss = 1.549293, iou_loss = 3.871156, total_loss = 5.420449
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.700307), count: 4, class_loss = 0.691832, iou_loss = 10.754625, total_loss = 11.446458
#  total_bbox = 398133, rewritten_bbox = 0.964753 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.824051), count: 10, class_loss = 0.622834, iou_loss = 3.948151, total_loss = 4.570985
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.746169), count: 7, class_loss = 1.720985, iou_loss = 53.126122, total_loss = 54.847107
#  total_bbox = 398150, rewritten_bbox = 0.964712 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.869750), count: 6, class_loss = 0.294789, iou_loss = 2.522585, total_loss = 2.817373
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.840394), count: 2, class_loss = 0.184795, iou_loss = 4.887745, total_loss = 5.072540
#  total_bbox = 398158, rewritten_bbox = 0.964692 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.850157), count: 4, class_loss = 0.249104, iou_loss = 1.906866, total_loss = 2.155971
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.623934), count: 3, class_loss = 0.628215, iou_loss = 4.891558, total_loss = 5.519773
#  total_bbox = 398165, rewritten_bbox = 0.964675 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.817601), count: 11, class_loss = 1.155728, iou_loss = 3.862499, total_loss = 5.018227
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.727533), count: 7, class_loss = 1.654600, iou_loss = 13.767472, total_loss = 15.422072
#  total_bbox = 398183, rewritten_bbox = 0.964632 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1914/2000: loss=0.9 hours left=0.1
#  1914: 0.863230, 0.724214 avg loss, 0.000026 rate, 2.601071 seconds, 122496 images, 0.089587 hours left
# Loaded: 0.000067 seconds
# ...
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.828134), count: 8, class_loss = 0.881251, iou_loss = 24.614967, total_loss = 25.496218
#  total_bbox = 416070, rewritten_bbox = 0.961136 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.807177), count: 13, class_loss = 0.897184, iou_loss = 3.494184, total_loss = 4.391368
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.764040), count: 9, class_loss = 0.869958, iou_loss = 13.984739, total_loss = 14.854697
#  total_bbox = 416092, rewritten_bbox = 0.961086 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.572071), count: 3, class_loss = 0.754848, iou_loss = 1.013220, total_loss = 1.768068
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.000000), count: 1, class_loss = 0.000513, iou_loss = 0.000000, total_loss = 0.000513
#  total_bbox = 416095, rewritten_bbox = 0.961079 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.747377), count: 5, class_loss = 0.588400, iou_loss = 1.275725, total_loss = 1.864125
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.767546), count: 2, class_loss = 0.327484, iou_loss = 2.587138, total_loss = 2.914622
#  total_bbox = 416102, rewritten_bbox = 0.961062 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.752365), count: 14, class_loss = 1.226052, iou_loss = 4.132955, total_loss = 5.359007
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.781684), count: 1, class_loss = 0.415074, iou_loss = 2.909549, total_loss = 3.324623
#  total_bbox = 416117, rewritten_bbox = 0.961028 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.814127), count: 7, class_loss = 0.868032, iou_loss = 2.353391, total_loss = 3.221423
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.851236), count: 5, class_loss = 0.485016, iou_loss = 6.798874, total_loss = 7.283890
#  total_bbox = 416129, rewritten_bbox = 0.961000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.834926), count: 10, class_loss = 1.250127, iou_loss = 3.076264, total_loss = 4.326392
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.800008), count: 16, class_loss = 2.703949, iou_loss = 24.313545, total_loss = 27.017494
#  total_bbox = 416155, rewritten_bbox = 0.960940 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1998/2000: loss=0.7 hours left=0.1
#  1998: 0.715340, 0.768401 avg loss, 0.000026 rate, 2.869708 seconds, 127872 images, 0.055330 hours left
# Loaded: 0.000071 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.786096), count: 15, class_loss = 1.320085, iou_loss = 5.870790, total_loss = 7.190874
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.783357), count: 5, class_loss = 0.929409, iou_loss = 10.923171, total_loss = 11.852580
#  total_bbox = 416175, rewritten_bbox = 0.961134 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.862614), count: 4, class_loss = 0.227726, iou_loss = 1.658423, total_loss = 1.886150
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.819647), count: 11, class_loss = 1.255055, iou_loss = 24.151434, total_loss = 25.406488
#  total_bbox = 416190, rewritten_bbox = 0.961100 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.881732), count: 3, class_loss = 0.142387, iou_loss = 0.941588, total_loss = 1.083975
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.687952), count: 7, class_loss = 1.602276, iou_loss = 10.212555, total_loss = 11.814831
#  total_bbox = 416200, rewritten_bbox = 0.961076 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.789288), count: 11, class_loss = 1.237048, iou_loss = 2.667784, total_loss = 3.904832
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.787251), count: 2, class_loss = 0.766981, iou_loss = 9.154101, total_loss = 9.921082
#  total_bbox = 416213, rewritten_bbox = 0.961046 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.735617), count: 2, class_loss = 0.470595, iou_loss = 0.713217, total_loss = 1.183811
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.868025), count: 2, class_loss = 0.207425, iou_loss = 5.866505, total_loss = 6.073929
#  total_bbox = 416217, rewritten_bbox = 0.961037 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.851656), count: 6, class_loss = 0.299818, iou_loss = 2.999914, total_loss = 3.299731
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.727707), count: 4, class_loss = 0.899956, iou_loss = 5.493769, total_loss = 6.393725
#  total_bbox = 416227, rewritten_bbox = 0.961014 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.877388), count: 2, class_loss = 0.255458, iou_loss = 0.701946, total_loss = 0.957403
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.917845), count: 1, class_loss = 0.003141, iou_loss = 1.568225, total_loss = 1.571366
#  total_bbox = 416230, rewritten_bbox = 0.961007 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.755879), count: 3, class_loss = 0.234535, iou_loss = 0.665020, total_loss = 0.899556
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.866263), count: 2, class_loss = 0.086201, iou_loss = 2.537745, total_loss = 2.623947
#  total_bbox = 416235, rewritten_bbox = 0.960996 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.806861), count: 17, class_loss = 2.417293, iou_loss = 5.988931, total_loss = 8.406223
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.745083), count: 46, class_loss = 8.371010, iou_loss = 85.531548, total_loss = 93.902557
#  total_bbox = 416298, rewritten_bbox = 0.960850 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.861684), count: 7, class_loss = 0.213444, iou_loss = 3.090679, total_loss = 3.304123
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.000000), count: 1, class_loss = 0.027698, iou_loss = 0.000000, total_loss = 0.027698
#  total_bbox = 416305, rewritten_bbox = 0.960834 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.738438), count: 2, class_loss = 0.297203, iou_loss = 0.714047, total_loss = 1.011249
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.831721), count: 3, class_loss = 0.308678, iou_loss = 4.024998, total_loss = 4.333676
#  total_bbox = 416310, rewritten_bbox = 0.960822 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.863154), count: 3, class_loss = 0.181137, iou_loss = 0.881921, total_loss = 1.063058
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.855362), count: 2, class_loss = 0.070243, iou_loss = 4.362816, total_loss = 4.433059
#  total_bbox = 416315, rewritten_bbox = 0.960811 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.786927), count: 12, class_loss = 1.789979, iou_loss = 3.390572, total_loss = 5.180551
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.780905), count: 6, class_loss = 0.845713, iou_loss = 5.692267, total_loss = 6.537981
#  total_bbox = 416333, rewritten_bbox = 0.960769 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.797338), count: 9, class_loss = 0.444230, iou_loss = 3.486865, total_loss = 3.931095
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.695475), count: 5, class_loss = 0.762640, iou_loss = 8.956072, total_loss = 9.718712
#  total_bbox = 416347, rewritten_bbox = 0.960977 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.877887), count: 5, class_loss = 0.011227, iou_loss = 2.324960, total_loss = 2.336187
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.834720), count: 2, class_loss = 0.208379, iou_loss = 5.140682, total_loss = 5.349061
#  total_bbox = 416354, rewritten_bbox = 0.960961 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.817223), count: 7, class_loss = 0.268402, iou_loss = 3.512320, total_loss = 3.780722
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.000000), count: 1, class_loss = 0.004125, iou_loss = 0.000000, total_loss = 0.004125
#  total_bbox = 416361, rewritten_bbox = 0.961185 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 1999/2000: loss=0.8 hours left=0.1
#  1999: 0.820606, 0.773621 avg loss, 0.000026 rate, 2.556209 seconds, 127936 images, 0.054793 hours left
# Loaded: 0.000103 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.816499), count: 2, class_loss = 0.182290, iou_loss = 0.677470, total_loss = 0.859759
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.828883), count: 2, class_loss = 0.409596, iou_loss = 6.183374, total_loss = 6.592970
#  total_bbox = 416365, rewritten_bbox = 0.961176 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.819865), count: 7, class_loss = 0.793685, iou_loss = 1.636863, total_loss = 2.430548
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.781771), count: 1, class_loss = 0.089895, iou_loss = 1.933146, total_loss = 2.023040
#  total_bbox = 416373, rewritten_bbox = 0.961157 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.845590), count: 6, class_loss = 0.260974, iou_loss = 2.157986, total_loss = 2.418961
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.742332), count: 8, class_loss = 1.128136, iou_loss = 27.826559, total_loss = 28.954695
#  total_bbox = 416387, rewritten_bbox = 0.961125 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.823813), count: 10, class_loss = 0.130285, iou_loss = 4.466802, total_loss = 4.597087
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.751182), count: 8, class_loss = 1.666575, iou_loss = 45.573181, total_loss = 47.239758
#  total_bbox = 416405, rewritten_bbox = 0.961084 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.833512), count: 7, class_loss = 0.097484, iou_loss = 3.792791, total_loss = 3.890275
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.000000), count: 1, class_loss = 0.015109, iou_loss = 0.000000, total_loss = 0.015109
#  total_bbox = 416412, rewritten_bbox = 0.961308 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.902989), count: 7, class_loss = 0.082791, iou_loss = 2.599366, total_loss = 2.682157
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.781159), count: 8, class_loss = 1.308008, iou_loss = 41.824120, total_loss = 43.132126
#  total_bbox = 416427, rewritten_bbox = 0.961273 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.852901), count: 2, class_loss = 0.035881, iou_loss = 0.756364, total_loss = 0.792245
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.851511), count: 1, class_loss = 0.001515, iou_loss = 1.138781, total_loss = 1.140297
#  total_bbox = 416430, rewritten_bbox = 0.961266 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.783443), count: 7, class_loss = 0.750318, iou_loss = 2.419847, total_loss = 3.170164
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.628089), count: 3, class_loss = 0.859537, iou_loss = 2.061217, total_loss = 2.920754
#  total_bbox = 416440, rewritten_bbox = 0.961243 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.851026), count: 5, class_loss = 0.683140, iou_loss = 1.005291, total_loss = 1.688431
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.716353), count: 1, class_loss = 0.359670, iou_loss = 0.955365, total_loss = 1.315035
#  total_bbox = 416446, rewritten_bbox = 0.961229 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.883120), count: 11, class_loss = 0.493817, iou_loss = 4.708257, total_loss = 5.202074
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.000000), count: 1, class_loss = 0.025385, iou_loss = 0.000000, total_loss = 0.025385
#  total_bbox = 416457, rewritten_bbox = 0.961204 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.753134), count: 4, class_loss = 0.787901, iou_loss = 0.826395, total_loss = 1.614296
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.000000), count: 1, class_loss = 0.013185, iou_loss = 0.000000, total_loss = 0.013185
#  total_bbox = 416461, rewritten_bbox = 0.961194 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.811179), count: 2, class_loss = 0.355579, iou_loss = 0.710685, total_loss = 1.066263
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.859801), count: 2, class_loss = 0.042045, iou_loss = 3.044862, total_loss = 3.086907
#  total_bbox = 416465, rewritten_bbox = 0.961185 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.825107), count: 8, class_loss = 1.024852, iou_loss = 3.974604, total_loss = 4.999455
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.752090), count: 2, class_loss = 0.489070, iou_loss = 12.680239, total_loss = 13.169309
#  total_bbox = 416475, rewritten_bbox = 0.961162 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.757559), count: 1, class_loss = 0.276941, iou_loss = 0.100166, total_loss = 0.377107
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.791264), count: 2, class_loss = 0.470080, iou_loss = 1.834380, total_loss = 2.304461
#  total_bbox = 416478, rewritten_bbox = 0.961155 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.806735), count: 14, class_loss = 1.091735, iou_loss = 3.462300, total_loss = 4.554036
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.855759), count: 3, class_loss = 0.280602, iou_loss = 5.734969, total_loss = 6.015571
#  total_bbox = 416495, rewritten_bbox = 0.961116 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 14 Avg (IOU: 0.780670), count: 4, class_loss = 0.586058, iou_loss = 0.668457, total_loss = 1.254515
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 21 Avg (IOU: 0.903883), count: 1, class_loss = 0.029525, iou_loss = 1.421912, total_loss = 1.451437
#  total_bbox = 416500, rewritten_bbox = 0.961104 %
#
#  Tensor Cores are disabled until the first 3000 iterations are reached.
# 2000/2000: loss=0.5 hours left=0.1
#  2000: 0.466244, 0.742884 avg loss, 0.000026 rate, 2.467258 seconds, 128000 images, 0.054252 hours left
# Saving weights to /content/drive/MyDrive/YoloV4/backup3/yolov4-tiny-obj_2000.weights
# Saving weights to /content/drive/MyDrive/YoloV4/backup3/yolov4-tiny-obj_last.weights
# Saving weights to /content/drive/MyDrive/YoloV4/backup3/yolov4-tiny-obj_final.weights
# If you want to train from the beginning, then use flag in the end of training command: -clear

# %% [markdown]
# # 開始測試

# %%
import os
import glob

# 切換到 darknet 目錄
os.chdir('/content/darknet')

# 定義資料夾路徑
train_folder = '/content/drive/MyDrive/YoloV4/train'
output_folder = '/content/drive/MyDrive/YoloV4/predicted_images'

# 確保輸出資料夾存在
os.makedirs(output_folder, exist_ok=True)

# 獲取所有圖片檔案
image_files = glob.glob(os.path.join(train_folder, '*'))

# 遍歷所有圖片
for image_file in image_files:
    # 執行 YOLO 檢測
    os.system(f"./darknet detector test /content/drive/MyDrive/YoloV4/coco.data \
        /content/drive/MyDrive/YoloV4/yolov4-tiny-obj.cfg \
        /content/drive/MyDrive/YoloV4/yolov4-tiny-obj_final.weights {image_file}")

    # 提取圖片檔名
    base_name = os.path.basename(image_file)
    predicted_name = os.path.splitext(base_name)[0] + "_prediction.jpg"

    # 移動預測圖片到指定目錄
    os.system(f"mv /content/darknet/predictions.jpg {os.path.join(output_folder, predicted_name)}")

# %%
import os
os.chdir('/content/darknet')
# !./darknet detector demo /content/drive/MyDrive/YoloV4/coco.data \
        /content/drive/MyDrive/YoloV4/yolov4-tiny-obj.cfg \
        /content/drive/MyDrive/YoloV4/backup3/yolov4-tiny-obj_final.weights \
        /content/drive/MyDrive/YoloV4/影片/youtube_2k9b98HXWlk_1920x1080_h264.mp4 \
        -out_filename /content/drive/MyDrive/YoloV4/影片/youtube_2k9b98HXWlk_predictions2.mp4
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#
#  cvWriteFrame
# Objects:
#
# car: 37%
#
# FPS:14.4 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 40%
#
# FPS:14.6 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 41%
#
# FPS:14.6 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 82%
#
# FPS:14.1 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 44%
#
# FPS:13.9 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 47%
#
# FPS:13.4 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 32%
#
# FPS:13.2 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.9 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 28%
#
# FPS:13.2 	 AVG_FPS:19.5
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:12.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 48%
#
# FPS:12.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 47%
#
# FPS:12.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 47%
#
# FPS:12.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 31%
#
# FPS:12.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 38%
#
# FPS:12.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:12.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 30%
#
# FPS:13.2 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 30%
#
# FPS:13.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 27%
#
# FPS:13.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.3 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.2 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.3 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 28%
# car: 28%
#
# FPS:13.4 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.2 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 29%
#
# FPS:13.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 38%
#
# FPS:13.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 48%
#
# FPS:12.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 31%
#
# FPS:13.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.0 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.9 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.8 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 30%
#
# FPS:19.9 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 27%
#
# FPS:19.0 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.7 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.3 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.4 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 25%
#
# FPS:23.3 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 32%
#
# FPS:22.6 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 26%
#
# FPS:22.0 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:21.6 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 25%
#
# FPS:21.9 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 26%
#
# FPS:21.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 50%
# car: 42%
#
# FPS:20.0 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 45%
#
# FPS:20.6 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 39%
# car: 29%
#
# FPS:21.0 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 38%
#
# FPS:21.3 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 40%
#
# FPS:21.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:20.7 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:13.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.8 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.9 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 25%
#
# FPS:19.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 48%
#
# FPS:18.9 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.9 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.4 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.2 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.2 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.7 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.9 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.3 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 41%
#
# FPS:20.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 41%
#
# FPS:20.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.4 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.8 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.9 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 47%
#
# FPS:20.4 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 62%
#
# FPS:20.1 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 50%
# car: 26%
#
# FPS:20.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 33%
#
# FPS:20.3 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 46%
#
# FPS:20.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 26%
#
# FPS:20.5 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 76%
#
# FPS:20.0 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 47%
#
# FPS:20.1 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 48%
#
# FPS:20.7 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 33%
#
# FPS:21.8 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 83%
#
# FPS:22.4 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 40%
#
# FPS:22.6 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 80%
#
# FPS:22.1 	 AVG_FPS:19.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 70%
#
# FPS:22.5 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 67%
#
# FPS:22.9 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 33%
# car: 29%
#
# FPS:22.5 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 48%
#
# FPS:21.8 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.8 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 45%
#
# FPS:22.9 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 40%
# car: 27%
#
# FPS:23.1 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:23.4 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 42%
# car: 38%
#
# FPS:23.5 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.9 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 37%
#
# FPS:23.9 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 31%
#
# FPS:24.4 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 43%
#
# FPS:24.2 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 29%
#
# FPS:23.8 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 27%
#
# FPS:24.5 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 29%
#
# FPS:24.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:25.0 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 29%
# car: 25%
#
# FPS:25.2 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 30%
#
# FPS:24.6 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.9 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.4 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.9 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 45%
#
# FPS:23.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.1 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.2 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.1 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 30%
#
# FPS:22.4 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.8 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 38%
#
# FPS:19.5 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 41%
#
# FPS:19.2 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:19.8
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 35%
#
# FPS:19.9 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 25%
#
# FPS:19.9 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 26%
#
# FPS:20.8 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:20.6 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 25%
#
# FPS:20.0 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.4 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 26%
#
# FPS:17.4 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.9 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 27%
#
# FPS:15.8 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.4 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.9 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 35%
#
# FPS:14.9 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.8 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.3 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.6 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.3 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.1 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.0 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.1 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.8 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 29%
#
# FPS:15.6 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 32%
#
# FPS:15.5 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 28%
#
# FPS:15.2 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 33%
#
# FPS:15.0 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 32%
#
# FPS:14.7 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 36%
#
# FPS:14.5 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 27%
#
# FPS:14.4 	 AVG_FPS:21.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.2 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 41%
# car: 35%
#
# FPS:13.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 29%
#
# FPS:13.7 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.7 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.2 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.4 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.2 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.4 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.4 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.3 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.4 	 AVG_FPS:15.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 26%
#
# FPS:24.7 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 26%
#
# FPS:24.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 28%
#
# FPS:24.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 48%
#
# FPS:24.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 28%
#
# FPS:25.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 33%
#
# FPS:27.7 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 32%
#
# FPS:28.2 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 27%
#
# FPS:28.5 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.2 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.2 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.1 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.8 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.4 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.0 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.9 	 AVG_FPS:17.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.1 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.3 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.3 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.6 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.9 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.7 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.6 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:32.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:32.1 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:31.6 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:32.1 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:31.6 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:31.0 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.5 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.0 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:30.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.5 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.3 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.3 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.5 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.9 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.5 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.6 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:26.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.2 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.8 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.9 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.7 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.5 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:29.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.8 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:28.0 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:25.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 36%
#
# FPS:25.1 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 30%
#
# FPS:26.4 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:27.4 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.4
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.0 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 29%
#
# FPS:20.7 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 34%
#
# FPS:19.6 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 27%
#
# FPS:18.3 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.9 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.2 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.1 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.0 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.8 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.7 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.6 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.9 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.6 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.2 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 33%
#
# FPS:15.0 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 45%
# car: 39%
#
# FPS:14.7 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 49%
# car: 42%
#
# FPS:14.7 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 59%
# car: 40%
#
# FPS:14.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 46%
# car: 32%
#
# FPS:14.5 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 38%
# car: 38%
# car: 28%
#
# FPS:14.2 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 46%
# car: 46%
#
# FPS:14.1 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 74%
# car: 31%
#
# FPS:15.2 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 61%
#
# FPS:15.4 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 63%
# car: 36%
#
# FPS:15.8 	 AVG_FPS:25.2
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 36%
#
# FPS:15.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 33%
#
# FPS:15.4 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 43%
# car: 36%
#
# FPS:15.6 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 85%
#
# FPS:15.5 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 83%
#
# FPS:15.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 87%
#
# FPS:15.0 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 75%
#
# FPS:15.0 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 80%
#
# FPS:15.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 65%
#
# FPS:14.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 73%
#
# FPS:14.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 70%
#
# FPS:14.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 80%
#
# FPS:14.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 82%
#
# FPS:14.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 71%
#
# FPS:16.0 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 78%
#
# FPS:16.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 79%
#
# FPS:15.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 77%
#
# FPS:15.4 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 79%
#
# FPS:15.7 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 79%
#
# FPS:16.3 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 75%
#
# FPS:16.5 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 75%
#
# FPS:16.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 78%
#
# FPS:16.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 83%
#
# FPS:17.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 83%
#
# FPS:19.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 78%
#
# FPS:20.2 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 77%
#
# FPS:20.6 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 74%
#
# FPS:21.5 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 66%
#
# FPS:22.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 72%
#
# FPS:22.5 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 53%
#
# FPS:22.3 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 69%
#
# FPS:23.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 75%
#
# FPS:23.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 77%
#
# FPS:22.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 70%
#
# FPS:23.7 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 60%
#
# FPS:25.3 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 69%
#
# FPS:24.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 53%
#
# FPS:24.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 45%
#
# FPS:24.5 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 49%
#
# FPS:24.0 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 60%
#
# FPS:24.0 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 65%
#
# FPS:23.5 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 69%
#
# FPS:23.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 60%
#
# FPS:23.3 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 46%
#
# FPS:24.0 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 49%
#
# FPS:25.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 59%
#
# FPS:25.2 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 49%
#
# FPS:24.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 40%
#
# FPS:24.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 49%
#
# FPS:26.4 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 48%
#
# FPS:26.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 55%
#
# FPS:26.3 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 52%
#
# FPS:26.4 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 44%
#
# FPS:26.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 40%
#
# FPS:26.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 33%
#
# FPS:26.4 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 41%
#
# FPS:26.3 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 61%
#
# FPS:26.3 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 69%
#
# FPS:25.8 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 71%
#
# FPS:25.0 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 73%
#
# FPS:27.1 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 69%
#
# FPS:27.7 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 69%
#
# FPS:27.9 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 67%
#
# FPS:27.3 	 AVG_FPS:15.3
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 73%
#
# FPS:27.4 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 72%
#
# FPS:27.7 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 67%
#
# FPS:27.9 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 62%
#
# FPS:28.3 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 55%
#
# FPS:28.4 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 62%
#
# FPS:27.7 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 62%
#
# FPS:27.5 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 56%
#
# FPS:27.2 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# Objects:
#
# car: 53%
# Stream closed.
#
# FPS:27.2 	 AVG_FPS:20.9
# OpenCV exception: show_image_mat
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.
